# %% [markdown]
# ![pandas](images\pandas.png)

# %% [markdown]
# ## 1 Setup

# %% [markdown]
# ### 1.1 Download Library

# %% [markdown]
# Download library using below commands:

# %% [markdown]
# #### Inside Jupyter Notebook/Lab

# %% [markdown]
# ```sh
# !pip install pandas
# ```

# %% [markdown]
# #### From terminal

# %% [markdown]
# ```sh
# pip install pandas
# ```
#
# or
#
# ```sh
# pip3 install pandas
# ```

# %%
# !pip install pandas

# %% [markdown]
# ### 1.2 Import Library

# %% [markdown]
# Import pandas library under the alias `pd`.

# %%
from datetime import datetime

import numpy as np
import pandas as pd

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
# Out:
# NumPy version: 2.4.1
# Pandas version: 3.0.0

# %% [markdown]
# ### 1.3 Introduction

# %% [markdown]
# #### Why Pandas?

# %% [markdown]
# 1. Pandas can hold **heterogeneous data**.
# 2. Pandas supports heterogeneous data but each **column is homogeneous** (i.e., all values are of same datatype).
# 3. It provides facilities for **data manipulation** such as
#    1. Data import
#    2. Conditional filtering
#    3. Aggregation
#    4. Querying
#    5. Data export
# 4. It **uses NumPy internally** hence we can directly pass NumPy arrays to Pandas.

# %% [markdown]
# ## 2 Create `DataFrame`

# %% [markdown]
# Lets create a sample Employee DataFrame

# %% [markdown]
# ### 2.1 Using Python `dict`

# %%
employee_data = {
    "EmpName": ["Alex", "Ajax", "Jane", "John", "Anna"],
    "EmpAge": [31, 31, 28, 35, 40],
    "EmpRole": ["Senior SD", "Associate Architect", "Junior SD", "Architect", "V.P."],
    "D.O.J": ["10-06-2021", "23-01-2025", "13-03-2023", "01-12-2022", "03-08-2000"],
}

emp_df = pd.DataFrame(data=employee_data)
emp_df
# Out:
#   EmpName  EmpAge              EmpRole       D.O.J
# 0    Alex      31            Senior SD  10-06-2021
# 1    Ajax      31  Associate Architect  23-01-2025
# 2    Jane      28            Junior SD  13-03-2023
# 3    John      35            Architect  01-12-2022
# 4    Anna      40                 V.P.  03-08-2000

# %% [markdown]
# ### 2.2 Using Python `list`

# %%
employee_rows = [
    ["Alex", 31, "Senior SD", "01-06-2021"],
    ["Ajax", 31, "Associate Architect", "01-01-2025"],
    ["Jane", 28, "Junior SD", "01-03-2023"],
    ["John", 35, "Architect", "01-12-2022"],
    ["Anna", 40, "V.P.", "01-08-2000"],
]
column_names = ["EmpName", "EmpAge", "EmpRole", "D.O.J"]

emp_df = pd.DataFrame(data=employee_rows, columns=column_names)
emp_df
# Out:
#   EmpName  EmpAge              EmpRole       D.O.J
# 0    Alex      31            Senior SD  01-06-2021
# 1    Ajax      31  Associate Architect  01-01-2025
# 2    Jane      28            Junior SD  01-03-2023
# 3    John      35            Architect  01-12-2022
# 4    Anna      40                 V.P.  01-08-2000

# %% [markdown]
# > **Note**:
# >
# > Passing values to `columns` attribute is **NOT** mandatory, if no values are passed then they are indexed from 0 (to 3 in this case).

# %% [markdown]
# ### 2.3 `DataFrame`

# %% [markdown]
# #### What is a `DataFrame`?

# %% [markdown]
# 1. Tabular representation of data in pandas is called as DataFrame.
# 2. DataFrame contains **heterogeneous** data.

# %%
type(emp_df)
# Out:
# pandas.DataFrame

# %% [markdown]
# #### `DataFrame` Metadata

# %% [markdown]
# ##### `info()` Method

# %%
emp_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   EmpName  5 non-null      str
#  1   EmpAge   5 non-null      int64
#  2   EmpRole  5 non-null      str
#  3   D.O.J    5 non-null      str
# dtypes: int64(1), str(3)
# memory usage: 292.0 bytes

# %% [markdown]
# <div style="display: inline-block">
#
# |   # | Metadata                                             | Example                          |
# | --: | :--------------------------------------------------- | :------------------------------- |
# |   1 | Index range and row count.                           | RangeIndex: 5 entries, 0 to 4    |
# |   2 | Column count in DataFrame.                           | Data columns (total 4 columns)   |
# |   3 | Default indices.                                     | [0, 1, 2, 3, ...]                |
# |   4 | Column names.                                        | Column:'EmpName', 'EmpAge', etc. |
# |   5 | Missing value count in each column.                  | Non-Null Count: 5 non-null       |
# |   6 | Datatype of each column.                             | Dtype: 'str', 'int64', etc.      |
# |   7 | Overall size of DataFrame when loaded on to the RAM. | memory usage: 292.0 bytes        |
#
# </div>

# %% [markdown]
# ##### `shape` Attribute

# %%
emp_df.shape
# Out:
# (5, 4)

# %% [markdown]
# ### 2.4 `Series`

# %% [markdown]
# #### What is a `Series`?

# %% [markdown]
# 1. A NumPy array extracted from a DataFrame is called as Series.
# 2. Series contain homogeneous data.

# %%
emp_df["EmpName"]  # emp_df.EmpName
# Out:
# 0    Alex
# 1    Ajax
# 2    Jane
# 3    John
# 4    Anna
# Name: EmpName, dtype: str

# %%
type(emp_df.EmpName)
# Out:
# pandas.Series

# %% [markdown]
# #### `Series` Metadata

# %% [markdown]
# ##### `info()` Method

# %%
emp_df["EmpName"].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 5 entries, 0 to 4
# Series name: EmpName
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      str
# dtypes: str(1)
# memory usage: 172.0 bytes

# %% [markdown]
# ##### `shape` Attribute

# %%
emp_df["EmpName"].shape
# Out:
# (5,)

# %% [markdown]
# When multiple Series are stacked together it forms a DataFrame or in other words DataFrame is made up of multiple Series.

# %%
temp_df = emp_df[["EmpName", "EmpRole"]]
type(temp_df)
# Out:
# pandas.DataFrame

# %% [markdown]
# ### 2.5 Import data

# %% [markdown]
# Generally DataFrames are not created explicitly, instead data is imported/loaded into DataFrame from file or tables (from database).
#
# Lets create a DataFrame using this [CSV data file][1] downloaded from Kaggle.
#
# [1]: https://www.kaggle.com/datasets/anshumrankawat/mckinsey-csv

# %%
mk_df = pd.read_csv("data/mckinsey.csv")
mk_df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# > **Note**:
# > 1. Along with `.csv` pandas supports data import from different file types like `.txt`, `.xlsx`
# > 2. Data can also be imported from SQL tables refer [docs][1] for more details.
# > 3. Full list of supported formats: https://pandas.pydata.org/docs/reference/io.html
#
# [1]: https://pandas.pydata.org/docs/reference/io.html#sql

# %% [markdown]
# ### 2.6 Axis

# %% [markdown]
# Since pandas internally uses NumPy arrays, same axis rules that apply for 2D NumPy array applies to pandas.
#
# <div style="display: inline-block">
#
# | Index | Axis   | R vs C | Orientation |
# | ----: | :----- | :----- | :---------- |
# |     0 | Y-axis | Row    | Vertical    |
# |     1 | X-axis | Column | Horizontal  |
#
# </div>
#
# > **Note**:
# >
# > This is applicable only for 2D NumPy arrays.

# %% [markdown]
# ## 3 Helper Methods

# %% [markdown]
# ### 3.1 Preview data

# %% [markdown]
# There are three most frequently used DataFrame methods for previewing data:
#
# 1. `head()` method
# 2. `tail()` method
# 3. `sample()` method

# %% [markdown]
# #### `head()` Method

# %% [markdown]
# ##### Default

# %%
mk_df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %% [markdown]
# ##### Custom

# %%
mk_df.head(7)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439

# %% [markdown]
# #### `tail()` Method

# %% [markdown]
# ##### Default

# %%
mk_df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %% [markdown]
# ##### Custom

# %%
mk_df.tail(3)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %% [markdown]
# #### `sample()` Method

# %% [markdown]
# ##### Default

# %%
mk_df.sample()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1512  Tanzania  1952     8322925    Africa    41.215  716.650072

# %% [markdown]
# ##### Custom

# %%
mk_df.sample(5)
# Out:
#          country  year  population continent  life_exp      gdp_cap
# 781      Jamaica  1957     1535090  Americas    62.610  4756.525781
# 299        China  2007  1318683096      Asia    72.961  4959.114854
# 1432   Sri Lanka  1972    13016733      Asia    65.042  1213.395530
# 1019  Montenegro  2007      684736    Europe    74.543  9253.896111
# 794        Japan  1962    95831757      Asia    68.730  6576.649461

# %% [markdown]
# #### `describe()` Method

# %%
mk_df.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %% [markdown]
# ### 3.2 DataFrame Helper Methods

# %% [markdown]
# #### `info()` Method

# %% [markdown]
# Applying `info()` Method on DataFrame gives following details:
#
# 1. Coulm and row indices.
# 2. Name and datatype of each column.
# 3. Count of non values for each column.
# 4. Space occupied by DataFrame in RAM.

# %%
mk_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   str
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   str
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), str(2)
# memory usage: 80.0 KB

# %% [markdown]
# #### `keys()` Method

# %%
mk_df.keys()
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='str')

# %%
mk_df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='str')

# %% [markdown]
# #### `nunique()` Method

# %% [markdown]
# `nunique()` method when applied on DataFrame gives cardinality of each column.

# %%
mk_df.nunique()
# Out:
# country        142
# year            12
# population    1704
# continent        5
# life_exp      1626
# gdp_cap       1704
# dtype: int64

# %% [markdown]
# #### `value_counts()` Method

# %%
emp_df.value_counts()
# Out:
# EmpName  EmpAge  EmpRole              D.O.J
# Alex     31      Senior SD            01-06-2021    1
# Ajax     31      Associate Architect  01-01-2025    1
# Jane     28      Junior SD            01-03-2023    1
# John     35      Architect            01-12-2022    1
# Anna     40      V.P.                 01-08-2000    1
# Name: count, dtype: int64

# %% [markdown]
# ### 3.3 Series Helper Methods

# %% [markdown]
# #### `info()` Method

# %%
mk_df.population.info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 1704 entries, 0 to 1703
# Series name: population
# Non-Null Count  Dtype
# --------------  -----
# 1704 non-null   int64
# dtypes: int64(1)
# memory usage: 13.4 KB

# %% [markdown]
# #### `unique()` Method

# %%
mk_df["continent"].unique()
# Out:
# <StringArray>
# ['Asia', 'Europe', 'Africa', 'Americas', 'Oceania']
# Length: 5, dtype: str

# %%
x = pd.Series([4, 0, 1, np.nan, 4, np.nan, 4, 0])
x.nunique()
# Out:
# 3

# %% [markdown]
# > **Note**:
# >
# > `nunique()` does not count/consider `NaN` value.

# %% [markdown]
# #### `value_counts()` Method

# %%
mk_df["continent"].value_counts()
# Out:
# continent
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: count, dtype: int64

# %%
x = pd.Series([4, 0, 1, np.nan, 4, np.nan, 4, 0])
x.value_counts()
# Out:
# 4.0    3
# 0.0    2
# 1.0    1
# Name: count, dtype: int64

# %% [markdown]
# > **Note**:
# >
# > `value_counts()` does not count/consider `NaN` value.

# %% [markdown]
# ## 4 Index

# %% [markdown]
# ### 4.1 Column Index

# %% [markdown]
# #### Explicit Indexes

# %% [markdown]
# ##### Display column explicit indices

# %% [markdown]
# ###### Example 1

# %%
tmp_df = pd.DataFrame([["Alex", 31, "Senior SD"]])
tmp_df
# Out:
#       0   1          2
# 0  Alex  31  Senior SD

# %%
print("Different ways of accessing explicit indices:")

display(tmp_df.keys())
display(tmp_df.columns)
display(tmp_df.columns.values)
# Out:
# Different ways of accessing explicit indices:
# RangeIndex(start=0, stop=3, step=1)
# RangeIndex(start=0, stop=3, step=1)
# array([0, 1, 2])

# %% [markdown]
# ###### Example 2

# %%
print("Column explicit indices:")
emp_df.columns
# Out:
# Column explicit indices:
# Index(['EmpName', 'EmpAge', 'EmpRole', 'D.O.J'], dtype='str')

# %% [markdown]
# ##### Update column explicit indices

# %% [markdown]
# ###### Before

# %%
emp_df
# Out:
#   EmpName  EmpAge              EmpRole       D.O.J
# 0    Alex      31            Senior SD  01-06-2021
# 1    Ajax      31  Associate Architect  01-01-2025
# 2    Jane      28            Junior SD  01-03-2023
# 3    John      35            Architect  01-12-2022
# 4    Anna      40                 V.P.  01-08-2000

# %%
emp_df.columns = ["Name", "Age", "Role", "DOJ"]
emp_df.columns
# Out:
# Index(['Name', 'Age', 'Role', 'DOJ'], dtype='str')

# %% [markdown]
# ###### After

# %%
emp_df
# Out:
#    Name  Age                 Role         DOJ
# 0  Alex   31            Senior SD  01-06-2021
# 1  Ajax   31  Associate Architect  01-01-2025
# 2  Jane   28            Junior SD  01-03-2023
# 3  John   35            Architect  01-12-2022
# 4  Anna   40                 V.P.  01-08-2000

# %% [markdown]
# #### Implicit Indexes

# %% [markdown]
# 1. Implicit indices can only be assessed but not modified.
# 2. Implicit indices can be sliced in pythonic way (end index is exclusive). Discussed in `iloc`.

# %% [markdown]
# ##### Display column implicit indices

# %% [markdown]
# ###### Example 1

# %%
print("Explicit column indices:")
display(tmp_df.columns)

print("\nImplicit column indices:")
[tmp_df.columns.get_loc(c_name) for c_name in tmp_df.columns]
# Out:
# Explicit column indices:
# RangeIndex(start=0, stop=3, step=1)
# Implicit column indices:
# [0, 1, 2]

# %% [markdown]
# ###### Example 2

# %%
print("Explicit column indices:")
display(emp_df.columns)

print("\nImplicit column indices:")
[emp_df.columns.get_loc(c_name) for c_name in emp_df.columns]
# Out:
# Explicit column indices:
# Index(['Name', 'Age', 'Role', 'DOJ'], dtype='str')
# Implicit column indices:
# [0, 1, 2, 3]

# %% [markdown]
# ### 4.2 Row Index

# %% [markdown]
# #### Explicit Indexes

# %% [markdown]
# ##### Display row explicit indices

# %% [markdown]
# ###### Example 1

# %%
emp_df.index.values
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# ###### Example 2

# %%
mk_df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703], shape=(1704,))

# %% [markdown]
# ##### Update row explicit indices

# %% [markdown]
# ###### Before

# %%
emp_df
# Out:
#    Name  Age                 Role         DOJ
# 0  Alex   31            Senior SD  01-06-2021
# 1  Ajax   31  Associate Architect  01-01-2025
# 2  Jane   28            Junior SD  01-03-2023
# 3  John   35            Architect  01-12-2022
# 4  Anna   40                 V.P.  01-08-2000

# %%
emp_df.index = ["E01", "E02", "E03", "E04", "E05"]
emp_df.index.values
# Out:
# <StringArray>
# ['E01', 'E02', 'E03', 'E04', 'E05']
# Length: 5, dtype: str

# %% [markdown]
# ###### After

# %%
emp_df
# Out:
#      Name  Age                 Role         DOJ
# E01  Alex   31            Senior SD  01-06-2021
# E02  Ajax   31  Associate Architect  01-01-2025
# E03  Jane   28            Junior SD  01-03-2023
# E04  John   35            Architect  01-12-2022
# E05  Anna   40                 V.P.  01-08-2000

# %% [markdown]
# #### Implicit Indexes

# %% [markdown]
# 1. Implicit indices can only be assessed but not modified.
# 2. Implicit indices can be sliced in pythonic way (end index is exclusive). Discussed in detail  in `iloc`.

# %% [markdown]
# ##### Display row implicit indices

# %%
print("Explicit row indices:")
display(emp_df.index.values)

print("\nImplicit row indices:")
[emp_df.index.get_loc(exp_idx) for exp_idx in emp_df.index]
# Out:
# Explicit row indices:
# <StringArray>
# ['E01', 'E02', 'E03', 'E04', 'E05']
# Length: 5, dtype: str
# Implicit row indices:
# [0, 1, 2, 3, 4]

# %% [markdown]
# ## 5 Rename

# %% [markdown]
# Behavior of `rename` function:
#
# 1. `rename` can be used to change existing column name or explicit row indices.
# 2. Calling `rename` by passing an iterable as first parameter with `axis` parameter set to 1 will update column names.
# 3. Calling `rename` by passing an iterable as first parameter with `axis` parameter set to 0 will update explicit row indices.
# 4. Calling `rename` by passing a `dict` to `columns` parameter will update column names.
# 5. Calling `rename` by passing a `dict` to `index` parameter will update explicit row indices.

# %% [markdown]
# ### 5.1 Rename Column Index

# %%
emp_df.rename(
    {
        "Name": "First name",
        "Age": "Age in Years",
        "Role": "Position",
        "DOJ": "Date of Joining",
    },
    axis=1,
)
# Out:
#     First name  Age in Years             Position Date of Joining
# E01       Alex            31            Senior SD      01-06-2021
# E02       Ajax            31  Associate Architect      01-01-2025
# E03       Jane            28            Junior SD      01-03-2023
# E04       John            35            Architect      01-12-2022
# E05       Anna            40                 V.P.      01-08-2000

# %% [markdown]
# #### Importance of `inplace`

# %% [markdown]
# 1. DataFrame is not updated with new column names since `inplace` parameter of `rename()` is not set to `True`.
# 2. Setting `inplace` parameter to `True` ensures the changes done are permanent.
# 3. All DML methods require this parameter to be set to `True` for permanent changes.

# %% [markdown]
# ##### Original DataFrame

# %%
emp_df
# Out:
#      Name  Age                 Role         DOJ
# E01  Alex   31            Senior SD  01-06-2021
# E02  Ajax   31  Associate Architect  01-01-2025
# E03  Jane   28            Junior SD  01-03-2023
# E04  John   35            Architect  01-12-2022
# E05  Anna   40                 V.P.  01-08-2000

# %%
emp_df.rename(columns={"DOJ": "DateOfJoining"}, inplace=True)

# %% [markdown]
# ##### Modified DataFrame

# %%
emp_df
# Out:
#      Name  Age                 Role DateOfJoining
# E01  Alex   31            Senior SD    01-06-2021
# E02  Ajax   31  Associate Architect    01-01-2025
# E03  Jane   28            Junior SD    01-03-2023
# E04  John   35            Architect    01-12-2022
# E05  Anna   40                 V.P.    01-08-2000

# %% [markdown]
# ### 5.2 Rename Row Index

# %%
emp_df.rename({"E02": "A65", "E05": "VP01"}, axis=0)
# Out:
#       Name  Age                 Role DateOfJoining
# E01   Alex   31            Senior SD    01-06-2021
# A65   Ajax   31  Associate Architect    01-01-2025
# E03   Jane   28            Junior SD    01-03-2023
# E04   John   35            Architect    01-12-2022
# VP01  Anna   40                 V.P.    01-08-2000

# %% [markdown]
# > **Note**:
# >
# > Original DataFrame is not updated since `inplace` is not set to `True`.

# %% [markdown]
# ## 6 Typecasting

# %% [markdown]
# ### 6.1 Typecasting `DataFrame`

# %%
temp = pd.DataFrame(
    data=[
        [1, 3.14, True, "Abc"],
        [2, 0.5, False, "Xyz"],
        [3, 0, 0, None],
    ],
    dtype=object,
)

display(temp)
temp.info()
# Out:
#    0     1      2     3
# 0  1  3.14   True   Abc
# 1  2   0.5  False   Xyz
# 2  3     0      0  None
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
#  2   2       3 non-null      object
#  3   3       2 non-null      object
# dtypes: object(4)
# memory usage: 228.0+ bytes

# %% [markdown]
# ### 6.2 Typecasting `Series`

# %% [markdown]
# In pandas columns can be typecast using `astype`

# %%
# Typecast each column.
temp[0] = temp[0].astype(int)
temp[1] = temp[1].astype(float)
temp[2] = temp[2].astype(bool)
temp[3] = temp[3].astype(str)

display(temp)
temp.info()
# Out:
#    0     1      2    3
# 0  1  3.14   True  Abc
# 1  2  0.50  False  Xyz
# 2  3  0.00  False  NaN
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      int64
#  1   1       3 non-null      float64
#  2   2       3 non-null      bool
#  3   3       2 non-null      str
# dtypes: bool(1), float64(1), int64(1), str(1)
# memory usage: 207.0 bytes

# %% [markdown]
# > **Note**:
# >
# > Typecasting reduced the size of DataFrame from ~228 bytes to ~207 bytes

# %% [markdown]
# #### Handling Dates

# %%
emp_df["DateOfJoining"] = pd.to_datetime(emp_df["DateOfJoining"], format="%d-%m-%Y")
emp_df["DateOfJoining"].info()
# Out:
# <class 'pandas.Series'>
# Index: 5 entries, E01 to E05
# Series name: DateOfJoining
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      datetime64[us]
# dtypes: datetime64[us](1)
# memory usage: 252.0+ bytes

# %% [markdown]
# `DateOfJoining` was converted from `object` to `datetime64[ns]`

# %% [markdown]
# ## 7 Read

# %% [markdown]
# Before accessing rows using indices lets update row indices of DataFrame to create distinction between row-explicit index and row-implicit index.

# %% [markdown]
# For the `mk_df` DataFrame, explicit row indices range from 0 to 1703 as seen below.

# %% [markdown]
# ##### Old Explicit Indices

# %%
mk_df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703], shape=(1704,))

# %%
mk_df.index = range(1, len(mk_df) + 1)

# %% [markdown]
# ##### New Explicit Indices

# %% [markdown]
# For the `mk_df` DataFrame, new explicit row indices range from 1 to 1704 as seen below.

# %%
mk_df.index.values
# Out:
# array([   1,    2,    3, ..., 1702, 1703, 1704], shape=(1704,))

# %% [markdown]
# ### 7.1 Access Rows

# %% [markdown]
# #### Direct Access

# %% [markdown]
# ##### Example #1

# %% [markdown]
# Sample `mk_df` for reference.

# %%
mk_df.sample(2)
# Out:
#       country  year  population continent  life_exp       gdp_cap
# 1400  Somalia  1987     6921858    Africa    44.501   1093.244963
# 570   Germany  1977    78160773    Europe    72.500  20512.921230

# %% [markdown]
# Explicit row index cannot be used directly with DataFrame. Trying to access rows using explicit row index throws error.

# %%
try:
    mk_df[1]
except KeyError as err:
    print("KeyError:", err)
# Out:
# KeyError: 1

# %%
try:
    mk_df[1, 2, 3]
except KeyError as err:
    print("KeyError:", err)
# Out:
# KeyError: (1, 2, 3)

# %% [markdown]
# But slicing works...

# %%
mk_df[100:115:5]
# Out:
#         country  year  population continent  life_exp       gdp_cap
# 101  Bangladesh  1972    70759295      Asia    45.252    630.233627
# 106  Bangladesh  1997   123315288      Asia    59.412    972.770035
# 111     Belgium  1962     9218400    Europe    70.250  10991.206760

# %% [markdown]
# ##### Example #2

# %% [markdown]
# Sample `emp_df` for reference.

# %%
emp_df.sample(2)
# Out:
#      Name  Age       Role DateOfJoining
# E04  John   35  Architect    2022-12-01
# E05  Anna   40       V.P.    2000-08-01

# %% [markdown]
# Trying to access rows using explicit row index throws error.

# %%
try:
    emp_df["E05"]
except KeyError as err:
    print("KeyError:", err)
# Out:
# KeyError: 'E05'

# %% [markdown]
# ##### Example #3

# %%
try:
    emp_df["E03", "E04", "EO5"]
except KeyError as err:
    print("KeyError:", err)
# Out:
# KeyError: ('E03', 'E04', 'EO5')

# %% [markdown]
# But slicing works...

# %%
emp_df["E03":"EO5"]
# Out:
#      Name  Age       Role DateOfJoining
# E03  Jane   28  Junior SD    2023-03-01
# E04  John   35  Architect    2022-12-01
# E05  Anna   40       V.P.    2000-08-01

# %% [markdown]
# #### Using `loc`

# %% [markdown]
# ##### Example #1

# %%
mk_df.head(3)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3  Afghanistan  1962    10267083      Asia    31.997  853.100710

# %%
mk_df.loc[1]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 1, dtype: object

# %% [markdown]
# ##### Example #2

# %%
emp_df.head(3)
# Out:
#      Name  Age                 Role DateOfJoining
# E01  Alex   31            Senior SD    2021-06-01
# E02  Ajax   31  Associate Architect    2025-01-01
# E03  Jane   28            Junior SD    2023-03-01

# %%
emp_df.loc["E03"]
# Out:
# Name                            Jane
# Age                               28
# Role                       Junior SD
# DateOfJoining    2023-03-01 00:00:00
# Name: E03, dtype: object

# %% [markdown]
# #### Using `iloc`

# %%
mk_df.iloc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 1, dtype: object

# %%
emp_df.iloc[2]
# Out:
# Name                            Jane
# Age                               28
# Role                       Junior SD
# DateOfJoining    2023-03-01 00:00:00
# Name: E03, dtype: object

# %% [markdown]
# ### 7.2 Access Columns

# %% [markdown]
# ##### Example #1

# %%
emp_df["Name"]
# Out:
# E01    Alex
# E02    Ajax
# E03    Jane
# E04    John
# E05    Anna
# Name: Name, dtype: str

# %% [markdown]
# Explicit row index can be used with Series.

# %%
emp_df["Name"]["E05"]
# Out:
# 'Anna'

# %% [markdown]
# ##### Example #2

# %%
mk_df["continent"].tail(3)
# Out:
# 1702    Africa
# 1703    Africa
# 1704    Africa
# Name: continent, dtype: str

# %% [markdown]
# Explicit row index can be used with Series.

# %%
mk_df["continent"][1702]
# Out:
# 'Africa'

# %%
mk_df.head(3)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3  Afghanistan  1962    10267083      Asia    31.997  853.100710

# %%
mk_df.loc[:2, "year":"continent"]
# Out:
#    year  population continent
# 1  1952     8425333      Asia
# 2  1957     9240934      Asia

# %% [markdown]
# ```python
# pd.Series(['a','b','c'], index=[1,2,2])
# print(a[2])
# ```

# %%
a = pd.Series(["a", "b", "c"], index=[1, 2, 2])
print(a[2])
# Out:
# 2    b
# 2    c
# dtype: str

# %%
mk_df["country"][1]
# Out:
# 'Afghanistan'

# %%
try:
    mk_df["country", "year", "population"]
except KeyError as err:
    print("KeyError:", err)
# Out:
# KeyError: ('country', 'year', 'population')

# %% [markdown]
# #### Using `loc` and `iloc`

# %%
# df.index = list(range(1, len(df)+1))
# df.head(10)

# %%
# df.loc[1:3]

# %%
# df.iloc[1:3]

# %% [markdown]
# iloc end index is exclusive and it works on implicit index.

# %%
# temp["column name 1"]

# %%
# temp.loc["a"]

# %%
# temp.loc[["a"]]

# %%
# temp.loc[["a", "c"]]

# %%
# temp.reset_index(drop=True)

# %%
# df.loc[9::-3]

# %% [markdown]
# ### 7.3 Access Index

# %%
# df.head(10)

# %%
# pd.DataFrame(df, columns=['country', 'year'])
# df.iloc[:, 0:2]

# %%
# df.nunique()

# %%
# df.iloc[:20]

# %% [markdown]
# ## 8 Insert

# %% [markdown]
# ### 8.1 Insert Row

# %% [markdown]
# #### Using `concat` Method

# %% [markdown]
# ##### Insert single row

# %%
# New employee record.
new_emp = [
    {
        "Name": "Bob",
        "Age": 30,
        "Role": "Junior SD",
        "DateOfJoining": "01-07-2024",
    }
]

# Create new DataFrame for new employee record.
new_emp_df1 = pd.DataFrame(data=new_emp)
new_emp_df1
# Out:
#   Name  Age       Role DateOfJoining
# 0  Bob   30  Junior SD    01-07-2024

# %% [markdown]
# Observe that new DataFrame has explicit index `0`

# %%
# Concatenate new DataFrame to main DataFrame.
emp_df = pd.concat([emp_df, new_emp_df1])
emp_df
# Out:
#      Name  Age                 Role        DateOfJoining
# E01  Alex   31            Senior SD  2021-06-01 00:00:00
# E02  Ajax   31  Associate Architect  2025-01-01 00:00:00
# E03  Jane   28            Junior SD  2023-03-01 00:00:00
# E04  John   35            Architect  2022-12-01 00:00:00
# E05  Anna   40                 V.P.  2000-08-01 00:00:00
# 0     Bob   30            Junior SD           01-07-2024

# %% [markdown]
# > **Note**:
# >
# > 1. If `ignore_index` parameter of `concat` method is not set to `True` then explicit indices from both the DataFrames are retained as it is.
# > 2. By default `ignore_index` is set to `False`.

# %% [markdown]
# Check explicit indices

# %%
emp_df.index
# Out:
# Index(['E01', 'E02', 'E03', 'E04', 'E05', 0], dtype='object')

# %% [markdown]
# Check implicit indices

# %%
[emp_df.index.get_loc(exp_idx) for exp_idx in emp_df.index]
# Out:
# [0, 1, 2, 3, 4, 5]

# %% [markdown]
# ##### Insert multiple rows

# %%
new_emps = [
    ["David", 30, "Junior SD", "01-07-2024"],
    ["Karen", 40, "Associate Architect", "01-07-2024"],
]
column_names = ["Name", "Age", "Role", "DateOfJoining"]

new_emp_df2 = pd.DataFrame(data=new_emps, columns=column_names)
new_emp_df2
# Out:
#     Name  Age                 Role DateOfJoining
# 0  David   30            Junior SD    01-07-2024
# 1  Karen   40  Associate Architect    01-07-2024

# %%
# Concatenate new DataFrame to main DataFrame.
emp_df = pd.concat([emp_df, new_emp_df2], axis=0, ignore_index=True)
emp_df
# Out:
#     Name  Age                 Role        DateOfJoining
# 0   Alex   31            Senior SD  2021-06-01 00:00:00
# 1   Ajax   31  Associate Architect  2025-01-01 00:00:00
# 2   Jane   28            Junior SD  2023-03-01 00:00:00
# 3   John   35            Architect  2022-12-01 00:00:00
# 4   Anna   40                 V.P.  2000-08-01 00:00:00
# 5    Bob   30            Junior SD           01-07-2024
# 6  David   30            Junior SD           01-07-2024
# 7  Karen   40  Associate Architect           01-07-2024

# %% [markdown]
# > **Note**:
# >
# > `concat()` method does not have `inplace` parameter.

# %%
emp_df["DateOfJoining"].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 8 entries, 0 to 7
# Series name: DateOfJoining
# Non-Null Count  Dtype
# --------------  -----
# 8 non-null      object
# dtypes: object(1)
# memory usage: 196.0+ bytes

# %%
emp_df["DateOfJoining"] = pd.to_datetime(emp_df["DateOfJoining"], format="%d-%m-%Y")

# %%
emp_df["DateOfJoining"].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 8 entries, 0 to 7
# Series name: DateOfJoining
# Non-Null Count  Dtype
# --------------  -----
# 8 non-null      datetime64[us]
# dtypes: datetime64[us](1)
# memory usage: 196.0 bytes

# %% [markdown]
# #### Using `loc` and `iloc`

# %% [markdown]
# ### 8.2 Insert Column

# %% [markdown]
# Columns can be directly added to DataFrame as shown in below examples:

# %% [markdown]
# #### Using direct assignment

# %% [markdown]
# ##### Example #1

# %% [markdown]
# Lets insert a new column called `Experinace` into `emp_df`

# %%
emp_df["Experinace"] = datetime(2026, 1, 1) - emp_df["DateOfJoining"]
emp_df
# Out:
#     Name  Age                 Role DateOfJoining Experinace
# 0   Alex   31            Senior SD    2021-06-01  1675 days
# 1   Ajax   31  Associate Architect    2025-01-01   365 days
# 2   Jane   28            Junior SD    2023-03-01  1037 days
# 3   John   35            Architect    2022-12-01  1127 days
# 4   Anna   40                 V.P.    2000-08-01  9284 days
# 5    Bob   30            Junior SD    2024-07-01   549 days
# 6  David   30            Junior SD    2024-07-01   549 days
# 7  Karen   40  Associate Architect    2024-07-01   549 days

# %% [markdown]
# ##### Example #2

# %%
mk_df["gdp"] = mk_df["gdp_cap"] * mk_df["population"]
mk_df.head(3)
# Out:
#        country  year  population continent  life_exp     gdp_cap           gdp
# 1  Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086e+09
# 2  Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449e+09
# 3  Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856e+09

# %% [markdown]
# #### Using `concat`

# %%
emp_gender = pd.DataFrame(
    data=["M", "M", "F", "M", "F", "M", "M", "F"],
    columns=["Gender"],
)
emp_gender.head(3)
# Out:
#   Gender
# 0      M
# 1      M
# 2      F

# %%
pd.concat([emp_df, emp_gender], axis=1)
# Out:
#     Name  Age                 Role DateOfJoining Experinace Gender
# 0   Alex   31            Senior SD    2021-06-01  1675 days      M
# 1   Ajax   31  Associate Architect    2025-01-01   365 days      M
# 2   Jane   28            Junior SD    2023-03-01  1037 days      F
# 3   John   35            Architect    2022-12-01  1127 days      M
# 4   Anna   40                 V.P.    2000-08-01  9284 days      F
# 5    Bob   30            Junior SD    2024-07-01   549 days      M
# 6  David   30            Junior SD    2024-07-01   549 days      M
# 7  Karen   40  Associate Architect    2024-07-01   549 days      F

# %%
# Concatenate new DataFrame to main DataFrame.
emp_df = pd.concat([emp_df, emp_gender], axis=1)
emp_df
# Out:
#     Name  Age                 Role DateOfJoining Experinace Gender
# 0   Alex   31            Senior SD    2021-06-01  1675 days      M
# 1   Ajax   31  Associate Architect    2025-01-01   365 days      M
# 2   Jane   28            Junior SD    2023-03-01  1037 days      F
# 3   John   35            Architect    2022-12-01  1127 days      M
# 4   Anna   40                 V.P.    2000-08-01  9284 days      F
# 5    Bob   30            Junior SD    2024-07-01   549 days      M
# 6  David   30            Junior SD    2024-07-01   549 days      M
# 7  Karen   40  Associate Architect    2024-07-01   549 days      F

# %% [markdown]
# #### Using `loc` and `iloc`

# %% [markdown]
# ## 9 Update

# %% [markdown]
# ### 9.1 Update Index

# %% [markdown]
# #### Using `index` Attribute

# %% [markdown]
# For the `mk_df` DataFrame, implicit row indices range from 0 to 1703 as seen below (1704 is exclusive).

# %% [markdown]
# ##### Before update

# %%
mk_df.index.values
# Out:
# array([   1,    2,    3, ..., 1702, 1703, 1704], shape=(1704,))

# %% [markdown]
# By default Explicit index is same as Implicit index. Default Explicit indices can be update as shown below:

# %%
mk_df.index = range(1, 1705)

# %% [markdown]
# ##### After update

# %%
mk_df.index.values
# Out:
# array([   1,    2,    3, ..., 1702, 1703, 1704], shape=(1704,))

# %% [markdown]
# #### Reset Index

# %% [markdown]
# ##### Without `drop` parameter

# %%
mk_df.reset_index().head(3)
# Out:
#    index      country  year  population continent  life_exp     gdp_cap  \
# 0      1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1      2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2      3  Afghanistan  1962    10267083      Asia    31.997  853.100710
#
#             gdp
# 0  6.567086e+09
# 1  7.585449e+09
# 2  8.758856e+09

# %% [markdown]
# > **Note**:
# >
# > In above call to `reset_index`, `inplace` parameter was purposefully not set to `True` for testing `drop` parameter next.

# %% [markdown]
# ##### With `drop` parameter

# %%
mk_df.reset_index(drop=True, inplace=True)
mk_df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap           gdp
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086e+09
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449e+09
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856e+09
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014e+09
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553e+09

# %% [markdown]
# > **Note**:
# >
# > In `reset_index` method `drop` parameter is set to `False` by default.

# %% [markdown]
# #### Set Index

# %% [markdown]
# ##### Before set index

# %%
emp_df
# Out:
#     Name  Age                 Role DateOfJoining Experinace Gender
# 0   Alex   31            Senior SD    2021-06-01  1675 days      M
# 1   Ajax   31  Associate Architect    2025-01-01   365 days      M
# 2   Jane   28            Junior SD    2023-03-01  1037 days      F
# 3   John   35            Architect    2022-12-01  1127 days      M
# 4   Anna   40                 V.P.    2000-08-01  9284 days      F
# 5    Bob   30            Junior SD    2024-07-01   549 days      M
# 6  David   30            Junior SD    2024-07-01   549 days      M
# 7  Karen   40  Associate Architect    2024-07-01   549 days      F

# %%
emp_df.set_index(keys="Name", inplace=True)

# %% [markdown]
# ##### After set index

# %%
emp_df
# Out:
#        Age                 Role DateOfJoining Experinace Gender
# Name
# Alex    31            Senior SD    2021-06-01  1675 days      M
# Ajax    31  Associate Architect    2025-01-01   365 days      M
# Jane    28            Junior SD    2023-03-01  1037 days      F
# John    35            Architect    2022-12-01  1127 days      M
# Anna    40                 V.P.    2000-08-01  9284 days      F
# Bob     30            Junior SD    2024-07-01   549 days      M
# David   30            Junior SD    2024-07-01   549 days      M
# Karen   40  Associate Architect    2024-07-01   549 days      F

# %% [markdown]
# > **Note**:
# >
# > `set_index` method also has `drop` parameter but it is set to `True` by default.

# %% [markdown]
# ### 9.2 Update Column

# %%
# df.index = list(range(1, len(df)+1))
# df

# %% [markdown]
# ### 9.3 Update Row

# %%
# test_df.iloc[3] = ["Row 4 Column 1", "Row 4 Column 2", "Row 4 Column 3"]

# %% [markdown]
# ## 10 Drop

# %% [markdown]
# ### 10.1 Deleting Rows (Explicit Indices)

# %% [markdown]
# #### Using `axis`

# %% [markdown]
# For the `mk_df` DataFrame:
# 1. Explicit row indices range from 1 to 1704.
# 2. Implicit row indices range from 0 to 1703.

# %% [markdown]
# ##### Before delete

# %%
mk_df.loc[801:805]
# Out:
#     country  year  population continent  life_exp       gdp_cap           gdp
# 801   Japan  1997   125956499      Asia    80.690  28816.584990  3.629636e+12
# 802   Japan  2002   127065841      Asia    82.000  28604.591900  3.634667e+12
# 803   Japan  2007   127467972      Asia    82.603  31656.068060  4.035135e+12
# 804  Jordan  1952      607914      Asia    43.158   1546.907807  9.403869e+08
# 805  Jordan  1957      746559      Asia    45.669   1886.080591  1.408070e+09

# %% [markdown]
# ##### Single row delete

# %%
mk_df.drop(802, axis=0, inplace=True)

# %% [markdown]
# ##### Multi row delete

# %%
mk_df.drop([803, 804], axis=0, inplace=True)

# %% [markdown]
# ##### After delete

# %%
mk_df.loc[801:805]
# Out:
#     country  year  population continent  life_exp       gdp_cap           gdp
# 801   Japan  1997   125956499      Asia    80.690  28816.584990  3.629636e+12
# 805  Jordan  1957      746559      Asia    45.669   1886.080591  1.408070e+09

# %% [markdown]
# #### Using `index` parameter

# %% [markdown]
# ##### Before delete

# %%
mk_df.loc[601:605]
# Out:
#        country  year  population continent  life_exp      gdp_cap  \
# 601  Guatemala  1957     3640876  Americas    44.142  2617.155967
# 602  Guatemala  1962     4208858  Americas    46.954  2750.364446
# 603  Guatemala  1967     4690773  Americas    50.016  3242.531147
# 604  Guatemala  1972     5149581  Americas    53.738  4031.408271
# 605  Guatemala  1977     5703430  Americas    56.029  4879.992748
#
#               gdp
# 601  9.528740e+09
# 602  1.157589e+10
# 603  1.520998e+10
# 604  2.076006e+10
# 605  2.783270e+10

# %% [markdown]
# ##### Single row delete

# %%
mk_df.drop(index=602, axis=0, inplace=True)

# %% [markdown]
# ##### Multi row delete

# %%
mk_df.drop(index=range(603, 605), inplace=True)

# %% [markdown]
# ##### After

# %%
mk_df.loc[601:605]
# Out:
#        country  year  population continent  life_exp      gdp_cap  \
# 601  Guatemala  1957     3640876  Americas    44.142  2617.155967
# 605  Guatemala  1977     5703430  Americas    56.029  4879.992748
#
#               gdp
# 601  9.528740e+09
# 605  2.783270e+10

# %% [markdown]
# ### 10.2 Deleting Columns

# %% [markdown]
# #### Using `axis`

# %% [markdown]
# ##### Before delete

# %%
mk_df.head(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap           gdp
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086e+09
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449e+09

# %% [markdown]
# ##### Single column delete

# %%
mk_df.drop("population", axis=1, inplace=True)

# %% [markdown]
# ##### Multi column delete

# %%
mk_df.drop(["life_exp", "country"], axis=1, inplace=True)

# %% [markdown]
# ##### After delete

# %%
mk_df.head(2)
# Out:
#    year continent     gdp_cap           gdp
# 0  1952      Asia  779.445314  6.567086e+09
# 1  1957      Asia  820.853030  7.585449e+09

# %% [markdown]
# #### Using `columns` parameter

# %% [markdown]
# ##### Before delete

# %%
mk_df.head(2)
# Out:
#    year continent     gdp_cap           gdp
# 0  1952      Asia  779.445314  6.567086e+09
# 1  1957      Asia  820.853030  7.585449e+09

# %% [markdown]
# ##### Single column delete

# %%
mk_df.drop(columns="continent", inplace=True)

# %% [markdown]
# ##### Multi column delete

# %%
mk_df.drop(columns=["gdp", "year", "gdp_cap"], inplace=True)

# %% [markdown]
# ##### After delete

# %%
mk_df.head(2)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1]
